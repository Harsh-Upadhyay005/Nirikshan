# %%
import pandas as pd

df = pd.read_csv(
    "../data/interim/Table6_engineered.csv",
)

df.head(10)
# Out:
#                      Ministry                            Category  \
# 0  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 1  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 2  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 3  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 4  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 5  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 6  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 7  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 8  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 9  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
#
#                                         Project Name  \
# 0  Construction of New Domestic Terminal Building...
# 1  Construction of New Integrated Terminal Buildi...
# 2  Construction of New Domestic Terminal Building...
# ...
