# %%
import pandas as pd

df = pd.read_csv(
    "../data/interim/all_projects_extracted1.csv"
)

df.head()
# Out:
#                                          0      1           2  \
# 0  APRIL 2026\nOngoing Projects State-Wise    NaN         NaN
# 1                                      NaN  Sl.No  STATE NAME
# 2                                      NaN      1    Offshore
# 3                                      NaN    NaN         NaN
# 4                                      NaN    NaN   PAN India
#
#                                      3                  4              5  \
# 0                                  NaN                NaN            NaN
# 1                         Allocated To             Sector  Project Count
# 2  Ministry of Petroleum & Natural Gas          Oil & Gas              7
# 3                 Ministry of Railways           Railways              1
# 4     Department of Telecommunications  Telecommunication              5
#
#                                                    6  \
# 0                                                NaN
# ...
