# %%
import pandas as pd

df = pd.read_csv(
    "../data/interim/all_projects_extracted1.csv",
    
)

df = df.drop(df.index[0]).reset_index(drop=True)

df.head(10)
# Out:
#      0      1                  2  \
# 0  NaN  Sl.No         STATE NAME
# 1  NaN      1           Offshore
# 2  NaN    NaN                NaN
# 3  NaN    NaN          PAN India
# 4  NaN    NaN                NaN
# 5  NaN    NaN                NaN
# 6  NaN      2  Andaman & Nicobar
# 7  NaN    NaN                NaN
# 8  NaN    NaN                NaN
# 9  NaN      3     Andhra Pradesh
#
#                                                    3                  4  \
# 0                                       Allocated To             Sector
# 1                Ministry of Petroleum & Natural Gas          Oil & Gas
# 2                               Ministry of Railways           Railways
# 3                   Department of Telecommunications  Telecommunication
# 4                               Ministry of Railways           Railways
# 5                                                NaN              Total
# 6                Ministry of Housing & Urban Affairs        Real Estate
# ...

# %%
df.columns = df.iloc[0]
df = df.iloc[1:].reset_index(drop=True)
df.head(10)
# Out:
# 0  NaN Sl.No         STATE NAME  \
# 0  NaN     1           Offshore
# 1  NaN   NaN                NaN
# 2  NaN   NaN          PAN India
# 3  NaN   NaN                NaN
# 4  NaN   NaN                NaN
# 5  NaN     2  Andaman & Nicobar
# 6  NaN   NaN                NaN
# 7  NaN   NaN                NaN
# 8  NaN     3     Andhra Pradesh
# 9  NaN   NaN                NaN
#
# 0                                       Allocated To             Sector  \
# 0                Ministry of Petroleum & Natural Gas          Oil & Gas
# 1                               Ministry of Railways           Railways
# 2                   Department of Telecommunications  Telecommunication
# 3                               Ministry of Railways           Railways
# 4                                                NaN              Total
# 5                Ministry of Housing & Urban Affairs        Real Estate
# 6              Ministry of Road Transport & Highways   Roads & Highways
# ...

# %%
df.sample(10)
# Out:
# 0     NaN Sl.No                                         STATE NAME  \
# 1658  NaN   682  New line Dahod-Indore via Sardarpur, Jabuwa an...
# 1544  NaN   583  4th LINE BETWEEN BAREJADI NANDEJ-SANAND-AHMEDA...
# 922   NaN    94  KOLGAON EXPANSION DEEP OC MINE\n(Western Coalf...
# 2629  NaN  1511  Construction of Greenfield Connectivity to Jew...
# 215   NaN   NaN                                                NaN
# 436   NaN    14  Bulk Loading Hub- Kanpur\n(MinistryofPetroleum...
# 2759  NaN  1623  4L of Greenfield section from  Sirhind to Moha...
# 1353  NaN   439  2G Ethanol Biorefinery at Bathinda\n(Hindustan...
# 1970  NaN   950  Estimate for Improvement to two lane with pave...
# 3068  NaN  1887  Improvement/construction of 2-lane with paved ...
#
# 0                                   Allocated To  \
# 1658  Multi-States \n(Gujarat, Madhya \nPradesh)
# 1544                                     Gujarat
# 922                                  Maharashtra
# ...
