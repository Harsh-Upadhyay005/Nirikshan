# %%
import pandas as pd

df = pd.read_csv(
    "../data/interim/paimana_table6.csv",
    
)

df.head(10)
# Out:
#    sl_no                    ministry                              sector  \
# 0      1  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 1      2  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 2      3  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 3      4  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 4      5  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 5      6  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 6      7  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 7      8  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 8      9  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
# 9     10  Ministry of Civil Aviation  Aviation & Aviation Infrastructure
#
#                                         project_name  \
# 0  Construction of New Domestic Terminal Building...
# 1  Construction of New Integrated Terminal Buildi...
# ...
